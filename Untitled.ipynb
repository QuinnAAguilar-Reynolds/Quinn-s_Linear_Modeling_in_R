# %%
#This note was made by me, Quinn. Literally the rest of this code was made by chatGPT. I simply used the Python code you demonstrated Thursday, gave it to cahtGPT and told it to do the same thing but in R. I am really gratful to get the oportunity to learn and test the capibilites of AI technology with fear of grade penalty.


# Load necessary libraries
library(ggplot2)

# Read the CSV file
df <- read.csv("regrex1.csv")

# Scatter plot of the data
ggplot(df, aes(x = x, y = y)) +
  geom_point() +
  labs(title = "Scatter Plot with Linear Regression Model",
       x = "x",
       y = "y") +
  theme_minimal()

# Fit the linear model
model <- lm(y ~ x, data = df)

# Get the R-squared value
r_sq <- summary(model)$r.squared
print(paste("R-squared:", r_sq))

# Predict the values
df$y_pred <- predict(model, df)

# Plot the data and the linear model
ggplot(df, aes(x = x, y = y)) +
  geom_point(color = 'blue', size = 3) +
  geom_line(aes(y = y_pred), color = 'red', size = 1) +
  labs(title = "Scatter Plot with Linear Regression Model",
       x = "x",
       y = "y") +
  theme_minimal()
# Out:
# [1] "R-squared: 0.929364155128174"
# plot without title
# plot without title
